# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.constants as cons

# %%
datos=np.loadtxt('IRCF.txt')

# %%
col1=datos[:,0:1]
col2=datos[:,1:2]
col3=datos[:,3:4]

# %%
w=plt.errorbar(col1,col2,col3,color='r' 
     )

# %%
h=cons.Planck

# %%
k=cons.Boltzmann

# %%
c=cons.speed_of_light

# %%
print h
# Out:
# 6.62607004e-34

# %%
print c
# Out:
# 299792458.0

# %%
print k
# Out:
# 1.38064852e-23

# %%
datos2=np.loadtxt('IRCF.txt').T

# %%
np.shape(datos2)
# Out:
# (5, 43)

# %%
x=datos2[0]
y=datos2[1]

# %%
plt.scatter(x,y,color='b')
plt.grid()

# %%
plt.errorbar()

# %%
datamode=np.loadtxt('IRCF.txt').T
v=datamode[0]
inte=datamode[1]/1e6
err=datamode[3]/1e3

# %%
graph=plt.errorbar(v,inte,err)

# %%
def intensidad(v,T):
    v=v*c*100
    pt1=h*v/(k*T)
    pt2=2.*h/c**2/1e-20 
    return pt2*v**3/(np.exp(pt1)-1.)

# %%
q=plt.plot(v,intensidad(v,2.7))
plt.grid()

# %%
fig=plt.figure(figsize=(10,7))
gs=plt.GridSpec(2,1,height_ratios=(0.03,0.01))
ax0=plt.subplot(gs[0])
ax0.errorbar(v,inte,yerr=err/1000,fmt='o')
ax1=plt.subplot(gs[1])
ax1.errorbar(v,v*0,yerr=err)
ax1.set_ylim(-100,90)
fig.subplots_adjust(hspace=0)
